# %%
from gemma import gemma_response

app = FastAPI()

@app.get("/")
def home():
    return {"message": "EdgeMind API Running"}

@app.post("/solve")
def solve(data: dict):
    grid = np.array(data["grid"])
    text = data.get("text", "")

    llm = gemma_response(text)
    result, rule = simple_reasoning(grid)

    return {
        "llm": llm,
        "rule_used": rule,
        "output": result.tolist()
    }
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_55/2658673670.py in <cell line: 0>()
# ----> 1 from gemma import gemma_response
#       2
#       3 app = FastAPI()
#       4
#       5 @app.get("/")
#
# ModuleNotFoundError: No module named 'gemma'
